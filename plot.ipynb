# %%
# Read csv

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pathlib import Path

# %%
path = Path('build/training_data') / 'engagement_0_man0.csv'
df = pd.read_csv(path)
df.columns
# Out:
# Index(['time', 'm_x', 'm_y', 'm_vx', 'm_vy', 'm_ax_cmd', 'm_ay_cmd', 'm_hd',
#        't_x', 't_y', 't_vx', 't_vy', 't_v', 't_a', 't_gam', 't_gamd', 'rel_x',
#        'rel_y', 'rel_r', 'rel_vx', 'rel_vy', 'rel_xlam', 'rel_xlamd', 'rel_vc',
#        'xh_xlam', 'xh_xlamd'],
#       dtype='object')

# %%
mx = df['m_x'].to_numpy()
my = df['m_y'].to_numpy()
tx = df['t_x'].to_numpy()
ty = df['t_y'].to_numpy()
plt.plot(mx, my)
plt.plot(tx, ty)
plt.grid()

# %%
a = df['t_a'].to_numpy()
time = df['time'].to_numpy()
time
# Out:
# array([0.00000e+00, 1.00000e-03, 2.00000e-03, ..., 1.00863e+01,
#        1.00864e+01, 1.00865e+01], shape=(10164,))
