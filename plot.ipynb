# %%
# Read csv

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pathlib import Path

# %%
path = Path('build') / 'sim.csv'
df = pd.read_csv(path)
df.columns
# Out:
# Index(['time', 'm_x', 'm_y', 'm_vx', 'm_vy', 'm_ax_cmd', 'm_ay_cmd', 'm_hd',
#        't_x', 't_y', 't_vx', 't_vy', 't_v', 't_a', 't_gam', 't_gamd', 'rel_x',
#        'rel_y', 'rel_r', 'rel_vx', 'rel_vy', 'rel_xlam', 'rel_xlamd', 'rel_vc',
#        'xh_xlam', 'xh_xlamd'],
#       dtype='object')

# %%
mx = df['m_x'].to_numpy()
my = df['m_y'].to_numpy()
tx = df['t_x'].to_numpy()
ty = df['t_y'].to_numpy()

# %%
t_a = df['t_a'].to_numpy()
t_a
# Out:
# array([ 49.05,  49.05,  49.05, ..., -49.05, -49.05, -49.05],
#       shape=(53405,))

# %%
plt.plot(mx, my)
plt.plot(tx, ty)
plt.grid()

# %%
ty
# Out:
# array([100000, 100001, 100002, ..., 151111, 151111, 151112],
#       shape=(53405,))

# %%
xh_lam = df['xh_xlam'].to_numpy()
xlam = df['rel_xlam'].to_numpy()
xh_lamd = df['xh_xlamd'].to_numpy()
xlamd = df['rel_xlamd'].to_numpy()
time = df['time'].to_numpy()

plt.plot(time, xlam)
plt.plot(time, xh_lam)
plt.grid()

# %%
ty
# Out:
# array([100000, 100001, 100002, ..., 151111, 151111, 151112],
#       shape=(53405,))
